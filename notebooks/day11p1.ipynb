# %%
import re

# %%
test_string = """Monkey 0:
  Starting items: 79, 98
  Operation: new = old * 19
  Test: divisible by 23
    If true: throw to monkey 2
    If false: throw to monkey 3

Monkey 1:
  Starting items: 54, 65, 75, 74
  Operation: new = old + 6
  Test: divisible by 19
    If true: throw to monkey 2
    If false: throw to monkey 0

Monkey 2:
  Starting items: 79, 60, 97
  Operation: new = old * old
  Test: divisible by 13
    If true: throw to monkey 1
    If false: throw to monkey 3

Monkey 3:
  Starting items: 74
  Operation: new = old + 3
  Test: divisible by 17
    If true: throw to monkey 0
    If false: throw to monkey 1"""

# %%
from dataclasses import dataclass


@dataclass
class Monkey:
    id: str = None,
    items: list = None,
    throw_to: dict = None,
    op: str = None,
    operand: str = None
    modulus: int = None
    others: dict = None
    inspect_count: int = 0
    
    def check(self):
        return self.id is not None and \
               self.items is not None and \
               self.throw_to is not None and \
               self.op is not None and \
               self.operand is not None and \
               self.modulus is not None
               
    def inspect(self, item):
        if self.operand == "old":
            if self.op == "+":
                return item*2
            if self.op == "*":
                return item**2
        else:
            if self.op == "+":
                return item+int(self.operand)
            if self.op == "*":
                return item*int(self.operand)
            
    def inspect_all(self):
        self.inspect_count += len(self.items)
        for i in range(len(self.items)):
            # print(f"Monkey {self.id} inspects {self.items[i]}, new worry {self.inspect(self.items[i]) // 3}")
            self.items[i] = self.inspect(self.items[i]) // 3
    
    def throw_item(self, item):
        other = self.others[self.throw_to[item % self.modulus == 0]]
        print(f"Monkey {self.id} throws {item} at Monkey {other.id}")
        other.items.append(item)
        
    def monkey_round(self):
        self.inspect_all()
        self.items.reverse()
        while len(self.items) > 0:
            self.throw_item(self.items.pop())

# %%
def parse(input: str) -> dict[Monkey]:
    monkey_buffer = None
    monkeys = {}
    for line in input.splitlines():
        line = line.strip()
        if len(line) == 0: continue
        if line.startswith("Monkey"):
            if monkey_buffer is not None: 
                if monkey_buffer.check():
                    monkeys[monkey_buffer.id] = monkey_buffer
                else:
                    raise ValueError(f"Malformed Monkey {monkey_buffer.id}")
            monkey_buffer = Monkey()
            monkey_buffer.id = int(re.search("Monkey ([\d]+):", line).groups()[0])
            monkey_buffer.items = []
            monkey_buffer.throw_to = {}
            monkey_buffer.others = monkeys
            continue
        if line.startswith("Starting items"):
            monkey_buffer.items = [int(x) for x in (re.search("Starting items: (.+)", line).groups()[0].split(","))]
            continue
        if line.startswith("Operation:"):
            op, operand = re.search("Operation: new = old (.) (.+)", line).groups()
            monkey_buffer.op = op
            monkey_buffer.operand = operand
            continue
        if line.startswith("Test"):
            monkey_buffer.modulus = int(re.search("Test: divisible by (\d+)", line).groups()[0])
            continue
        if line.startswith("If true"):
            monkey_buffer.throw_to[True] = int(re.search("If true: throw to monkey (\d+)", line).groups()[0])
            continue
        if line.startswith("If false"):
            monkey_buffer.throw_to[False] = int(re.search("If false: throw to monkey (\d+)", line).groups()[0])
            continue
        raise ValueError(f"Bad input: {line}")
    if monkey_buffer is not None: 
        if monkey_buffer.check():
            monkeys[monkey_buffer.id] = monkey_buffer
        else:
            raise ValueError(f"Malformed Monkey {monkey_buffer.id}")
    return monkeys

# %%
# monkeys = parse(open("../inputs/11.txt").read())
monkeys = parse(test_string)
for i in range(20):
    print(f"round {i}")
    for monkey in monkeys.values():
        monkey.monkey_round()

activity = sorted([monkey.inspect_count for monkey in monkeys.values()], reverse=True)
activity[0] * activity[1]
# Out:
# round 0
# Monkey 0 throws 500 at Monkey 3
# Monkey 0 throws 620 at Monkey 3
# Monkey 1 throws 20 at Monkey 0
# Monkey 1 throws 23 at Monkey 0
# Monkey 1 throws 27 at Monkey 0
# Monkey 1 throws 26 at Monkey 0
# Monkey 2 throws 2080 at Monkey 1
# Monkey 2 throws 1200 at Monkey 3
# Monkey 2 throws 3136 at Monkey 3
# Monkey 3 throws 25 at Monkey 1
# Monkey 3 throws 167 at Monkey 1
# Monkey 3 throws 207 at Monkey 1
# Monkey 3 throws 401 at Monkey 1
# Monkey 3 throws 1046 at Monkey 1
# round 1
# Monkey 0 throws 126 at Monkey 3
# Monkey 0 throws 145 at Monkey 3
# Monkey 0 throws 171 at Monkey 3
# Monkey 0 throws 164 at Monkey 3
# Monkey 1 throws 695 at Monkey 0
# Monkey 1 throws 10 at Monkey 0
# Monkey 1 throws 57 at Monkey 2
# Monkey 1 throws 71 at Monkey 0
# Monkey 1 throws 135 at Monkey 0
# Monkey 1 throws 350 at Monkey 0
# Monkey 2 throws 1083 at Monkey 3
# Monkey 3 throws 43 at Monkey 1
# Monkey 3 throws 49 at Monkey 1
# Monkey 3 throws 58 at Monkey 1
# Monkey 3 throws 55 at Monkey 1
# Monkey 3 throws 362 at Monkey 1
# round 2
# Monkey 0 throws 4401 at Monkey 3
# Monkey 0 throws 63 at Monkey 3
# Monkey 0 throws 449 at Monkey 3
# Monkey 0 throws 855 at Monkey 3
# Monkey 0 throws 2216 at Monkey 3
# Monkey 1 throws 16 at Monkey 0
# Monkey 1 throws 18 at Monkey 0
# Monkey 1 throws 21 at Monkey 0
# Monkey 1 throws 20 at Monkey 0
# Monkey 1 throws 122 at Monkey 0
# Monkey 3 throws 1468 at Monkey 1
# Monkey 3 throws 22 at Monkey 1
# Monkey 3 throws 150 at Monkey 1
# Monkey 3 throws 286 at Monkey 1
# Monkey 3 throws 739 at Monkey 1
# round 3
# Monkey 0 throws 101 at Monkey 3
# Monkey 0 throws 114 at Monkey 3
# Monkey 0 throws 133 at Monkey 3
# Monkey 0 throws 126 at Monkey 3
# Monkey 0 throws 772 at Monkey 3
# Monkey 1 throws 491 at Monkey 0
# Monkey 1 throws 9 at Monkey 0
# Monkey 1 throws 52 at Monkey 0
# Monkey 1 throws 97 at Monkey 0
# Monkey 1 throws 248 at Monkey 0
# Monkey 3 throws 34 at Monkey 0
# Monkey 3 throws 39 at Monkey 1
# Monkey 3 throws 45 at Monkey 1
# Monkey 3 throws 43 at Monkey 1
# Monkey 3 throws 258 at Monkey 1
# round 4
# Monkey 0 throws 3109 at Monkey 3
# Monkey 0 throws 57 at Monkey 3
# Monkey 0 throws 329 at Monkey 3
# Monkey 0 throws 614 at Monkey 3
# Monkey 0 throws 1570 at Monkey 3
# Monkey 0 throws 215 at Monkey 3
# Monkey 1 throws 15 at Monkey 0
# Monkey 1 throws 17 at Monkey 0
# Monkey 1 throws 16 at Monkey 0
# Monkey 1 throws 88 at Monkey 0
# Monkey 3 throws 1037 at Monkey 0
# Monkey 3 throws 20 at Monkey 1
# Monkey 3 throws 110 at Monkey 1
# Monkey 3 throws 205 at Monkey 1
# Monkey 3 throws 524 at Monkey 1
# Monkey 3 throws 72 at Monkey 1
# round 5
# Monkey 0 throws 95 at Monkey 3
# Monkey 0 throws 107 at Monkey 3
# Monkey 0 throws 101 at Monkey 3
# Monkey 0 throws 557 at Monkey 3
# Monkey 0 throws 6567 at Monkey 3
# Monkey 1 throws 8 at Monkey 0
# Monkey 1 throws 38 at Monkey 2
# Monkey 1 throws 70 at Monkey 0
# Monkey 1 throws 176 at Monkey 0
# Monkey 1 throws 26 at Monkey 0
# Monkey 2 throws 481 at Monkey 1
# Monkey 3 throws 32 at Monkey 1
# Monkey 3 throws 36 at Monkey 1
# Monkey 3 throws 34 at Monkey 0
# Monkey 3 throws 186 at Monkey 1
# Monkey 3 throws 2190 at Monkey 1
# round 6
# Monkey 0 throws 50 at Monkey 3
# Monkey 0 throws 443 at Monkey 3
# Monkey 0 throws 1114 at Monkey 3
# Monkey 0 throws 164 at Monkey 3
# Monkey 0 throws 215 at Monkey 3
# Monkey 1 throws 162 at Monkey 0
# Monkey 1 throws 12 at Monkey 0
# Monkey 1 throws 14 at Monkey 0
# Monkey 1 throws 64 at Monkey 0
# Monkey 1 throws 732 at Monkey 0
# Monkey 3 throws 17 at Monkey 0
# Monkey 3 throws 148 at Monkey 1
# Monkey 3 throws 372 at Monkey 1
# Monkey 3 throws 55 at Monkey 1
# Monkey 3 throws 72 at Monkey 1
# round 7
# Monkey 0 throws 1026 at Monkey 3
# Monkey 0 throws 76 at Monkey 3
# Monkey 0 throws 88 at Monkey 3
# Monkey 0 throws 405 at Monkey 3
# Monkey 0 throws 4636 at Monkey 3
# Monkey 0 throws 107 at Monkey 3
# Monkey 1 throws 51 at Monkey 0
# Monkey 1 throws 126 at Monkey 0
# Monkey 1 throws 20 at Monkey 0
# Monkey 1 throws 26 at Monkey 0
# Monkey 3 throws 343 at Monkey 1
# Monkey 3 throws 26 at Monkey 1
# Monkey 3 throws 30 at Monkey 1
# Monkey 3 throws 136 at Monkey 0
# Monkey 3 throws 1546 at Monkey 1
# Monkey 3 throws 36 at Monkey 1
# round 8
# Monkey 0 throws 323 at Monkey 3
# Monkey 0 throws 798 at Monkey 3
# Monkey 0 throws 126 at Monkey 3
# Monkey 0 throws 164 at Monkey 3
# Monkey 0 throws 861 at Monkey 3
# Monkey 1 throws 116 at Monkey 0
# Monkey 1 throws 10 at Monkey 0
# Monkey 1 throws 12 at Monkey 0
# Monkey 1 throws 517 at Monkey 0
# Monkey 1 throws 14 at Monkey 0
# Monkey 3 throws 108 at Monkey 1
# Monkey 3 throws 267 at Monkey 1
# Monkey 3 throws 43 at Monkey 1
# Monkey 3 throws 55 at Monkey 1
# Monkey 3 throws 288 at Monkey 1
# round 9
# Monkey 0 throws 734 at Monkey 3
# Monkey 0 throws 63 at Monkey 3
# Monkey 0 throws 76 at Monkey 3
# Monkey 0 throws 3274 at Monkey 3
# Monkey 0 throws 88 at Monkey 3
# Monkey 1 throws 38 at Monkey 2
# Monkey 1 throws 91 at Monkey 0
# Monkey 1 throws 16 at Monkey 0
# Monkey 1 throws 20 at Monkey 0
# Monkey 1 throws 98 at Monkey 0
# Monkey 2 throws 481 at Monkey 1
# Monkey 3 throws 245 at Monkey 1
# Monkey 3 throws 22 at Monkey 1
# Monkey 3 throws 26 at Monkey 1
# Monkey 3 throws 1092 at Monkey 1
# Monkey 3 throws 30 at Monkey 1
# round 10
# Monkey 0 throws 576 at Monkey 3
# Monkey 0 throws 101 at Monkey 3
# Monkey 0 throws 126 at Monkey 3
# Monkey 0 throws 620 at Monkey 3
# Monkey 1 throws 162 at Monkey 0
# Monkey 1 throws 83 at Monkey 0
# Monkey 1 throws 9 at Monkey 0
# Monkey 1 throws 10 at Monkey 0
# Monkey 1 throws 366 at Monkey 0
# Monkey 1 throws 12 at Monkey 0
# Monkey 3 throws 193 at Monkey 1
# Monkey 3 throws 34 at Monkey 0
# Monkey 3 throws 43 at Monkey 1
# Monkey 3 throws 207 at Monkey 1
# round 11
# Monkey 0 throws 1026 at Monkey 3
# Monkey 0 throws 525 at Monkey 3
# Monkey 0 throws 57 at Monkey 3
# Monkey 0 throws 63 at Monkey 3
# Monkey 0 throws 2318 at Monkey 3
# Monkey 0 throws 76 at Monkey 3
# Monkey 0 throws 215 at Monkey 3
# Monkey 1 throws 66 at Monkey 0
# Monkey 1 throws 16 at Monkey 0
# Monkey 1 throws 71 at Monkey 0
# Monkey 3 throws 343 at Monkey 1
# Monkey 3 throws 176 at Monkey 1
# Monkey 3 throws 20 at Monkey 1
# Monkey 3 throws 22 at Monkey 1
# Monkey 3 throws 773 at Monkey 1
# Monkey 3 throws 26 at Monkey 1
# Monkey 3 throws 72 at Monkey 1
# round 12
# Monkey 0 throws 418 at Monkey 3
# Monkey 0 throws 101 at Monkey 3
# Monkey 0 throws 449 at Monkey 3
# Monkey 1 throws 116 at Monkey 0
# Monkey 1 throws 60 at Monkey 0
# Monkey 1 throws 8 at Monkey 0
# Monkey 1 throws 9 at Monkey 0
# Monkey 1 throws 259 at Monkey 0
# Monkey 1 throws 10 at Monkey 0
# Monkey 1 throws 26 at Monkey 0
# Monkey 3 throws 140 at Monkey 1
# Monkey 3 throws 34 at Monkey 0
# Monkey 3 throws 150 at Monkey 1
# round 13
# Monkey 0 throws 734 at Monkey 3
# Monkey 0 throws 380 at Monkey 3
# Monkey 0 throws 50 at Monkey 3
# Monkey 0 throws 57 at Monkey 3
# Monkey 0 throws 1640 at Monkey 3
# Monkey 0 throws 63 at Monkey 3
# Monkey 0 throws 164 at Monkey 3
# Monkey 0 throws 215 at Monkey 3
# Monkey 1 throws 48 at Monkey 0
# Monkey 1 throws 52 at Monkey 0
# Monkey 3 throws 245 at Monkey 1
# Monkey 3 throws 127 at Monkey 1
# Monkey 3 throws 17 at Monkey 0
# Monkey 3 throws 20 at Monkey 1
# Monkey 3 throws 547 at Monkey 1
# Monkey 3 throws 22 at Monkey 1
# Monkey 3 throws 55 at Monkey 1
# Monkey 3 throws 72 at Monkey 1
# round 14
# Monkey 0 throws 304 at Monkey 3
# Monkey 0 throws 329 at Monkey 3
# Monkey 0 throws 107 at Monkey 3
# Monkey 1 throws 83 at Monkey 0
# Monkey 1 throws 44 at Monkey 0
# Monkey 1 throws 8 at Monkey 0
# Monkey 1 throws 184 at Monkey 0
# Monkey 1 throws 9 at Monkey 0
# Monkey 1 throws 20 at Monkey 0
# Monkey 1 throws 26 at Monkey 0
# Monkey 3 throws 102 at Monkey 0
# Monkey 3 throws 110 at Monkey 1
# Monkey 3 throws 36 at Monkey 1
# round 15
# Monkey 0 throws 525 at Monkey 3
# Monkey 0 throws 278 at Monkey 3
# Monkey 0 throws 50 at Monkey 3
# Monkey 0 throws 1165 at Monkey 3
# Monkey 0 throws 57 at Monkey 3
# Monkey 0 throws 126 at Monkey 3
# Monkey 0 throws 164 at Monkey 3
# Monkey 0 throws 646 at Monkey 3
# Monkey 1 throws 38 at Monkey 2
# Monkey 1 throws 14 at Monkey 0
# Monkey 2 throws 481 at Monkey 1
# Monkey 3 throws 176 at Monkey 1
# Monkey 3 throws 93 at Monkey 1
# Monkey 3 throws 17 at Monkey 0
# Monkey 3 throws 389 at Monkey 1
# Monkey 3 throws 20 at Monkey 1
# Monkey 3 throws 43 at Monkey 1
# Monkey 3 throws 55 at Monkey 1
# Monkey 3 throws 216 at Monkey 1
# round 16
# Monkey 0 throws 88 at Monkey 3
# Monkey 0 throws 107 at Monkey 3
# Monkey 1 throws 162 at Monkey 0
# Monkey 1 throws 60 at Monkey 0
# Monkey 1 throws 33 at Monkey 0
# Monkey 1 throws 131 at Monkey 0
# Monkey 1 throws 8 at Monkey 0
# Monkey 1 throws 16 at Monkey 0
# Monkey 1 throws 20 at Monkey 0
# Monkey 1 throws 74 at Monkey 0
# Monkey 3 throws 30 at Monkey 1
# Monkey 3 throws 36 at Monkey 1
# round 17
# Monkey 0 throws 1026 at Monkey 3
# Monkey 0 throws 380 at Monkey 3
# Monkey 0 throws 209 at Monkey 3
# Monkey 0 throws 829 at Monkey 3
# Monkey 0 throws 50 at Monkey 3
# Monkey 0 throws 101 at Monkey 3
# Monkey 0 throws 126 at Monkey 3
# Monkey 0 throws 468 at Monkey 3
# Monkey 1 throws 12 at Monkey 0
# Monkey 1 throws 14 at Monkey 0
# Monkey 3 throws 343 at Monkey 1
# Monkey 3 throws 127 at Monkey 1
# Monkey 3 throws 70 at Monkey 1
# Monkey 3 throws 277 at Monkey 1
# Monkey 3 throws 17 at Monkey 0
# Monkey 3 throws 34 at Monkey 0
# Monkey 3 throws 43 at Monkey 1
# Monkey 3 throws 157 at Monkey 1
# round 18
# Monkey 0 throws 76 at Monkey 3
# Monkey 0 throws 88 at Monkey 3
# Monkey 0 throws 107 at Monkey 3
# Monkey 0 throws 215 at Monkey 3
# Monkey 1 throws 116 at Monkey 0
# Monkey 1 throws 44 at Monkey 0
# Monkey 1 throws 25 at Monkey 0
# Monkey 1 throws 94 at Monkey 0
# Monkey 1 throws 16 at Monkey 0
# Monkey 1 throws 54 at Monkey 0
# Monkey 3 throws 26 at Monkey 1
# Monkey 3 throws 30 at Monkey 1
# Monkey 3 throws 36 at Monkey 1
# Monkey 3 throws 72 at Monkey 1
# round 19
# Monkey 0 throws 734 at Monkey 3
# Monkey 0 throws 278 at Monkey 3
# Monkey 0 throws 158 at Monkey 3
# Monkey 0 throws 595 at Monkey 3
# Monkey 0 throws 101 at Monkey 3
# Monkey 0 throws 342 at Monkey 3
# Monkey 1 throws 10 at Monkey 0
# Monkey 1 throws 12 at Monkey 0
# Monkey 1 throws 14 at Monkey 0
# Monkey 1 throws 26 at Monkey 0
# Monkey 3 throws 245 at Monkey 1
# Monkey 3 throws 93 at Monkey 1
# Monkey 3 throws 53 at Monkey 1
# Monkey 3 throws 199 at Monkey 1
# Monkey 3 throws 34 at Monkey 0
# Monkey 3 throws 115 at Monkey 1
# 10605
